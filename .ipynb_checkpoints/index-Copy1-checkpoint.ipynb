# %% [markdown]
# # COVID : Tracking the impact of COVID-19 in India

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read data set

# %%
#read data set
df1=pd.read_csv("https://api.covid19india.org/csv/latest/raw_data1.csv")
df2=pd.read_csv("https://api.covid19india.org/csv/latest/raw_data2.csv")
df3=pd.read_csv("https://api.covid19india.org/csv/latest/raw_data3.csv")
df4=pd.read_csv("https://api.covid19india.org/csv/latest/raw_data4.csv")
df5=pd.read_csv("https://api.covid19india.org/csv/latest/raw_data5.csv")

# %% [markdown]
# # Data Preparation
#
# 1) Here we have identified that column named (Num cases) which is present in raw_data1 and raw_data2 is renamed as (Num cases) in further data sets.
#     So, We are renaming column Num cases to avoid confusion. <br><br>
# 2) Drop Column(Estimated Onset Date) and (Backup Notes) from raw_data1 and raw_data2 : No use and not present in further data sets.

# %%
df1=df1.rename(columns={"Num cases": "Num Cases"})
df1=df1.drop(['Estimated Onset Date', 'Backup Notes'], axis=1)

df2=df2.rename(columns={"Num cases": "Num Cases"})
df2=df2.drop(['Estimated Onset Date', 'Backup Notes'], axis=1)

# %%
# Apppend all Data Set into Single Data set
df=df1.append(df2).append(df3).append(df4).append(df5)

# %%
# Row count
df.shape
## 76861
# Out:
# (76861, 20)

# %%
# Null value on Num Case
dfd=df[df['Num Cases'].isnull()]
dfd
# Out:
#        Patient Number State Patient Number Date Announced Age Bracket Gender  \
# 268           28160.0                  NaN     27/04/2020         NaN    NaN
# 12585         69740.0                  NaN     31/05/2020         NaN    NaN
# 12586         69741.0                  NaN     31/05/2020         NaN    NaN
#
#       Detected City Detected District Detected State State code  \
# 268             NaN               NaN            NaN        NaN
# 12585           NaN               NaN            NaN        NaN
# 12586           NaN               NaN            NaN        NaN
#
#       Current Status                                              Notes  \
# 268        Recovered  Tamil Nadu split on entry 1014 below. Not remo...
# 12585      Recovered                                                NaN
# 12586      Recovered                                                NaN
#
#       Contracted from which Patient (Suspected) Nationality  \
# ...

# %% [markdown]
# We do not need these record for null value.

# %%
df=df.dropna(subset=['Num Cases'])

# %%
print("Till here total No of case are",df['Num Cases'].sum())
## 334192.0
# Out:
# Till here total No of case are 334192.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76858 entries, 0 to 20437
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Patient Number                             76367 non-null  float64
#  1   State Patient Number                       15555 non-null  object
#  2   Date Announced                             76858 non-null  object
#  3   Age Bracket                                30751 non-null  object
#  4   Gender                                     33408 non-null  object
#  5   Detected City                              5204 non-null   object
#  6   Detected District                          69348 non-null  object
#  7   Detected State                             76853 non-null  object
#  8   State code                                 76853 non-null  object
#  9   Current Status                             76856 non-null  object
# ...

# %% [markdown]
# dfgroup=df[['State code','Num Cases']]
# gk = dfgroup.groupby('State code')
# gk.first()
# df['State code'].value_counts()

# %%
dfgroup=df[['State code','Num Cases']].groupby("State code")

# %%
xyz=dfgroup.sum().reset_index()
xyz
# Out:
#    State code  Num Cases
# 0          AN       55.0
# 1          AP     6450.0
# 2          AR       42.0
# 3          AS     2557.0
# 4          BR     6542.0
# 5          CH      512.0
# 6          CT      949.0
# 7          DL    34630.0
# 8          DN       15.0
# 9          GA      216.0
# 10         GJ    31967.0
# 11         HP      543.0
# 12         HR     4226.0
# 13         JH     1183.0
# 14         JK     4082.0
# 15         KA     5788.0
# 16         KL     1948.0
# 17         LA      127.0
# 18         MH   112654.0
# 19         ML       46.0
# 20         MN      160.0
# 21         MP    14371.0
# 22         MZ       18.0
# 23         NL       80.0
# 24         OR     3932.0
# 25         PB     4403.0
# 26         PY      132.0
# 27         RJ    16509.0
# 28         SK        2.0
# 29         TG     4498.0
# 30         TN    41336.0
# 31         TR      819.0
# 32         UN     7483.0
# 33         UP    14568.0
# 34         UT     1438.0
# 35         WB     9874.0

# %%
type(xyz)
# Out:
# pandas.core.frame.DataFrame

# %%
ax = xyz[['Num Cases','State code']].plot(kind='bar',
                                    figsize=(14,8),
                                    title="State wise confirmed case in India")
ax.set_xlabel("State List")
ax.set_ylabel("Confirmed Case")
# Out:
# Text(0, 0.5, 'Confirmed Case')

# %%
df=xyz[['State code','Num Cases']]
df
# Out:
#    State code  Num Cases
# 0          AN       55.0
# 1          AP     6450.0
# 2          AR       42.0
# 3          AS     2557.0
# 4          BR     6542.0
# 5          CH      512.0
# 6          CT      949.0
# 7          DL    34630.0
# 8          DN       15.0
# 9          GA      216.0
# 10         GJ    31967.0
# 11         HP      543.0
# 12         HR     4226.0
# 13         JH     1183.0
# 14         JK     4082.0
# 15         KA     5788.0
# 16         KL     1948.0
# 17         LA      127.0
# 18         MH   112654.0
# 19         ML       46.0
# 20         MN      160.0
# 21         MP    14371.0
# 22         MZ       18.0
# 23         NL       80.0
# 24         OR     3932.0
# 25         PB     4403.0
# 26         PY      132.0
# 27         RJ    16509.0
# 28         SK        2.0
# 29         TG     4498.0
# 30         TN    41336.0
# 31         TR      819.0
# 32         UN     7483.0
# 33         UP    14568.0
# 34         UT     1438.0
# 35         WB     9874.0

# %%
def plot_bargraph_with_groupings(df, groupby, colourby, title, xlabel, ylabel):
    """
    Plots a dataframe showing the frequency of datapoints grouped by one column and coloured by another.
    df : dataframe
    groupby: the column to groupby
    colourby: the column to color by
    title: the graph title
    xlabel: the x label,
    ylabel: the y label
    """

    import matplotlib.patches as mpatches

    # Makes a mapping from the unique colourby column items to a random color.
    ind_col_map = {x:y for x, y in zip(df[colourby].unique(),
                               [plt.cm.Paired(np.arange(len(df[colourby].unique())))][0])}


    # Find when the indicies of the soon to be bar graphs colors.
    unique_comb = df[[groupby, colourby]].drop_duplicates()
    name_ind_map = {x:y for x, y in zip(unique_comb[groupby], unique_comb[colourby])}
    c = df[groupby].index.map(lambda x: ind_col_map[name_ind_map[x]])

    # Makes the bargraph.
    ax = df[groupby].plot(kind='bar',
                                         figsize=FIG_SIZE,
                                         title=title,
                                         color=[c.values])
    # Makes a legend using the ind_col_map
    legend_list = []
    for key in ind_col_map.keys():
        legend_list.append(mpatches.Patch(color=ind_col_map[key], label=key))

    # display the graph.
    plt.legend(handles=legend_list)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

# %%
xyz=df['State code'].value_counts()


y = df['State code'].values
y[0:5]

# %%
df2 = df.copy('Patient Number')

df['loan_status'].value_counts()

df2['binned'] = pd.cut(df['Patient Number'])
df2

# %%
dfgroup.sort_values(['State code', 'Num Cases'], inplace=True)
dfgroup

dfgroup = pd.concat([g for _, g in dfgroup])

print(dfgroup)

# %%
dfgroup=df[['State code','Num Cases']]

# %%
dfgroup

by_comp = dfgroup.groupby("State code")

# %%
xyz=by_comp.sum()
xyz.sort_values(by=['Num Cases'], inplace=True,ascending=False)
xyz

# %%
ax = dfgroup['State code'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for each Owner Name")
ax.set_xlabel("Sate ")
ax.set_ylabel("Frequency")

# %%
dfgroup
