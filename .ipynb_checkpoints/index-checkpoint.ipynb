# %% [markdown]
# # COVID : Tracking the impact of COVID-19 in India

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read data set

# %%
#read data set
df1=pd.read_csv("https://api.covid19india.org/csv/latest/raw_data1.csv")
df2=pd.read_csv("https://api.covid19india.org/csv/latest/raw_data2.csv")
df3=pd.read_csv("https://api.covid19india.org/csv/latest/raw_data3.csv")
df4=pd.read_csv("https://api.covid19india.org/csv/latest/raw_data4.csv")
df5=pd.read_csv("https://api.covid19india.org/csv/latest/raw_data5.csv")

# %% [markdown]
# # Data Preparation
#
# 1) Here we have identified that column named (Num cases) which is present in raw_data1 and raw_data2 is renamed as (Num cases) in further data sets.
#     So, We are renaming column Num cases to avoid confusion. <br><br>
# 2) Drop Column(Estimated Onset Date) and (Backup Notes) from raw_data1 and raw_data2 : No use and not present in further data sets.

# %%
df1=df1.rename(columns={"Num cases": "Num Cases"})
df1=df1.drop(['Estimated Onset Date', 'Backup Notes'], axis=1)

df2=df2.rename(columns={"Num cases": "Num Cases"})
df2=df2.drop(['Estimated Onset Date', 'Backup Notes'], axis=1)

# %%
# Apppend all Data Set into Single Data set
df=df1.append(df2).append(df3).append(df4).append(df5)

# %%
# Row count
df.shape
## 76861
# Out:
# (76861, 20)

# %%
# Null value on Num Case
dfnan=df[df['Num Cases'].isnull()]
dfnan
# Out:
#        Patient Number State Patient Number Date Announced Age Bracket Gender  \
# 268           28160.0                  NaN     27/04/2020         NaN    NaN
# 12585         69740.0                  NaN     31/05/2020         NaN    NaN
# 12586         69741.0                  NaN     31/05/2020         NaN    NaN
#
#       Detected City Detected District Detected State State code  \
# 268             NaN               NaN            NaN        NaN
# 12585           NaN               NaN            NaN        NaN
# 12586           NaN               NaN            NaN        NaN
#
#       Current Status                                              Notes  \
# 268        Recovered  Tamil Nadu split on entry 1014 below. Not remo...
# 12585      Recovered                                                NaN
# 12586      Recovered                                                NaN
#
#       Contracted from which Patient (Suspected) Nationality  \
# 268                                         NaN         NaN
# 12585                                       NaN         NaN
# 12586                                       NaN         NaN
#
#       Type of transmission Status Change Date  \
# 268                    NaN                NaN
# 12585                  NaN                NaN
# 12586                  NaN                NaN
#
#                                                 Source_1 Source_2 Source_3  \
# 268    https://stopcorona.tn.gov.in/wp-content/upload...      NaN      NaN
# 12585                                                NaN      NaN      NaN
# 12586  https://twitter.com/RanchiPIB/status/126679803...      NaN      NaN
#
#        Num Cases  Entry_ID
# 268          NaN     269.0
# 12585        NaN   40804.0
# 12586        NaN   40805.0

# %% [markdown]
# We do not need these record for null value.

# %%
df=df.dropna(subset=['Num Cases'])

# %%
df
# Out:
#        Patient Number State Patient Number Date Announced Age Bracket Gender  \
# 0                 1.0             KL-TS-P1     30/01/2020          20      F
# 1                 2.0             KL-AL-P1     02/02/2020         NaN    NaN
# 2                 3.0             KL-KS-P1     03/02/2020         NaN    NaN
# 3                 4.0                DL-P1     02/03/2020          45      M
# 4                 5.0                TS-P1     02/03/2020          24      M
# ...               ...                  ...            ...         ...    ...
# 20433             NaN                  NaN     04/06/2020         NaN    NaN
# 20434             NaN                  NaN     04/06/2020         NaN    NaN
# 20435             NaN                  NaN     04/06/2020         NaN    NaN
# 20436             NaN                  NaN     04/06/2020         NaN    NaN
# 20437             NaN                  NaN     04/06/2020         NaN    NaN
#
#                   Detected City Detected District Detected State State code  \
# 0                      Thrissur          Thrissur         Kerala         KL
# 1                     Alappuzha         Alappuzha         Kerala         KL
# 2                     Kasaragod         Kasaragod         Kerala         KL
# 3      East Delhi (Mayur Vihar)        East Delhi          Delhi         DL
# 4                     Hyderabad         Hyderabad      Telangana         TG
# ...                         ...               ...            ...        ...
# 20433                       NaN         Alappuzha         Kerala         KL
# 20434                       NaN         Alappuzha         Kerala         KL
# 20435                       NaN         Alappuzha         Kerala         KL
# 20436                       NaN         Alappuzha         Kerala         KL
# 20437                       NaN         Alappuzha         Kerala         KL
#
#       Current Status                                              Notes  \
# 0          Recovered                               Travelled from Wuhan
# 1          Recovered                               Travelled from Wuhan
# 2          Recovered                               Travelled from Wuhan
# 3          Recovered                      Travelled from Austria, Italy
# 4          Recovered  Travelled from Dubai to Bangalore on 20th Feb,...
# ...              ...                                                ...
# 20433   Hospitalized                             Travelled from Chennai
# 20434   Hospitalized                              Travelled from Kuwait
# 20435   Hospitalized                     Travelled from Mumbai to Kochi
# 20436   Hospitalized             Travelled from Moscow landed at Kannur
# 20437   Hospitalized                              Travelled from Kuwait
#
#       Contracted from which Patient (Suspected) Nationality  \
# 0                                           NaN       India
# 1                                           NaN       India
# 2                                           NaN       India
# 3                                           NaN       India
# 4                                           NaN       India
# ...                                         ...         ...
# 20433                                       NaN         NaN
# 20434                                       NaN         NaN
# 20435                                       NaN         NaN
# 20436                                       NaN         NaN
# 20437                                       NaN         NaN
#
#       Type of transmission Status Change Date  \
# 0                 Imported         14/02/2020
# 1                 Imported         14/02/2020
# 2                 Imported         14/02/2020
# 3                 Imported         15/03/2020
# 4                 Imported         02/03/2020
# ...                    ...                ...
# 20433                  NaN                NaN
# 20434                  NaN                NaN
# 20435                  NaN                NaN
# 20436                  NaN                NaN
# 20437                  NaN                NaN
#
#                                                 Source_1  \
# 0      https://twitter.com/vijayanpinarayi/status/122...
# 1      https://www.indiatoday.in/india/story/kerala-r...
# 2      https://www.indiatoday.in/india/story/kerala-n...
# 3      https://www.indiatoday.in/india/story/not-a-ja...
# 4      https://www.deccanherald.com/national/south/qu...
# ...                                                  ...
# 20433  http://dhs.kerala.gov.in/wp-content/uploads/20...
# 20434  http://dhs.kerala.gov.in/wp-content/uploads/20...
# 20435  http://dhs.kerala.gov.in/wp-content/uploads/20...
# 20436  http://dhs.kerala.gov.in/wp-content/uploads/20...
# 20437  http://dhs.kerala.gov.in/wp-content/uploads/20...
#
#                                                 Source_2  \
# 0      https://weather.com/en-IN/india/news/news/2020...
# 1      https://weather.com/en-IN/india/news/news/2020...
# 2      https://twitter.com/ANI/status/122422148580539...
# 3      https://economictimes.indiatimes.com/news/poli...
# 4      https://www.indiatoday.in/india/story/coronavi...
# ...                                                  ...
# 20433  https://www.manoramaonline.com/district-news/a...
# 20434  https://www.manoramaonline.com/district-news/a...
# 20435  https://www.manoramaonline.com/district-news/a...
# 20436  https://www.manoramaonline.com/district-news/a...
# 20437  https://www.manoramaonline.com/district-news/a...
#
#                                                 Source_3  Num Cases  Entry_ID
# 0                                                    NaN        1.0       NaN
# 1                                                    NaN        1.0       NaN
# 2      https://weather.com/en-IN/india/news/news/2020...        1.0       NaN
# 3                                                    NaN        1.0       NaN
# 4      https://www.thehindu.com/news/national/coronav...        1.0       NaN
# ...                                                  ...        ...       ...
# 20433                                                NaN        1.0   48764.0
# 20434                                                NaN        1.0   48765.0
# 20435                                                NaN        1.0   48766.0
# 20436                                                NaN        1.0   48767.0
# 20437                                                NaN        1.0   48768.0
#
# [76858 rows x 20 columns]

# %%
print("Till here total No of case are",df['Num Cases'].sum())
## 334192.0
# Out:
# Till here total No of case are 334192.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76858 entries, 0 to 20437
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Patient Number                             76367 non-null  float64
#  1   State Patient Number                       15555 non-null  object
#  2   Date Announced                             76858 non-null  object
#  3   Age Bracket                                30751 non-null  object
#  4   Gender                                     33408 non-null  object
#  5   Detected City                              5204 non-null   object
#  6   Detected District                          69349 non-null  object
#  7   Detected State                             76853 non-null  object
#  8   State code                                 76853 non-null  object
#  9   Current Status                             76856 non-null  object
#  10  Notes                                      33614 non-null  object
#  11  Contracted from which Patient (Suspected)  1922 non-null   object
#  12  Nationality                                2709 non-null   object
#  13  Type of transmission                       2990 non-null   object
#  14  Status Change Date                         27780 non-null  object
#  15  Source_1                                   75403 non-null  object
#  16  Source_2                                   4463 non-null   object
#  17  Source_3                                   494 non-null    object
#  18  Num Cases                                  76858 non-null  float64
#  19  Entry_ID                                   48673 non-null  float64
# dtypes: float64(3), object(17)
# memory usage: 12.3+ MB

# %% [markdown]
# dfgroup=df[['State code','Num Cases']]
# gk = dfgroup.groupby('State code')
# gk.first()
# df['State code'].value_counts()

# %%
dfgroup=df[['State code','Num Cases']].groupby("State code").sum()
dfgroup

## dfgroup.reset_index()
# Out:
#             Num Cases
# State code
# AN               55.0
# AP             6450.0
# AR               42.0
# AS             2557.0
# BR             6542.0
# CH              512.0
# CT              949.0
# DL            34630.0
# DN               15.0
# GA              216.0
# GJ            31967.0
# HP              543.0
# HR             4226.0
# JH             1183.0
# JK             4082.0
# KA             5788.0
# KL             1948.0
# LA              127.0
# MH           112654.0
# ML               46.0
# MN              160.0
# MP            14371.0
# MZ               18.0
# NL               80.0
# OR             3932.0
# PB             4403.0
# PY              132.0
# RJ            16509.0
# SK                2.0
# TG             4498.0
# TN            41336.0
# TR              819.0
# UN             7483.0
# UP            14568.0
# UT             1438.0
# WB             9874.0

# %%
ax = dfgroup['Num Cases'].plot(kind='bar',
                                    figsize=(14,8),
                                    title="State wise confirmed case in India")
ax.set_xlabel("State List")
ax.set_ylabel("Confirmed Case")
# Out:
# Text(0, 0.5, 'Confirmed Case')

# %%
df.head(2)
# Out:
#    Patient Number State Patient Number Date Announced Age Bracket Gender  \
# 0             1.0             KL-TS-P1     30/01/2020          20      F
# 1             2.0             KL-AL-P1     02/02/2020         NaN    NaN
#
#   Detected City Detected District Detected State State code Current Status  \
# 0      Thrissur          Thrissur         Kerala         KL      Recovered
# 1     Alappuzha         Alappuzha         Kerala         KL      Recovered
#
#                   Notes Contracted from which Patient (Suspected) Nationality  \
# 0  Travelled from Wuhan                                       NaN       India
# 1  Travelled from Wuhan                                       NaN       India
#
#   Type of transmission Status Change Date  \
# 0             Imported         14/02/2020
# 1             Imported         14/02/2020
#
#                                             Source_1  \
# 0  https://twitter.com/vijayanpinarayi/status/122...
# 1  https://www.indiatoday.in/india/story/kerala-r...
#
#                                             Source_2 Source_3  Num Cases  \
# 0  https://weather.com/en-IN/india/news/news/2020...      NaN        1.0
# 1  https://weather.com/en-IN/india/news/news/2020...      NaN        1.0
#
#    Entry_ID
# 0       NaN
# 1       NaN

# %%
dfgender=df[['Gender','Num Cases']]
dfgender.head(4)
# Out:
#   Gender  Num Cases
# 0      F        1.0
# 1    NaN        1.0
# 2    NaN        1.0
# 3      M        1.0

# %%
dfgender['Gender'] = df['Gender'].fillna('NA')
# Out:
# C:\Users\Nitin Verma\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfgender.groupby('Gender').count()
# Out:
#             Num Cases
# Gender
# F               11356
# M               22047
# NA              43450
# Non-Binary          5

# %%
dfgender.apply(lambda x: item_check(df['Item']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3741c088bd60> in <module>
# ----> 1 dfgender.apply(lambda x: item_check(df['Item']))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-17-3741c088bd60> in <lambda>(x)
# ----> 1 dfgender.apply(lambda x: item_check(df['Item']))
#
# NameError: name 'item_check' is not defined

# %%
df[df['Current Status']=='Recovered']
